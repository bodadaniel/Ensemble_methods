# %% [markdown]
# <a href="https://colab.research.google.com/github/bodadaniel/Ensemble_methods/blob/main/Ensemble_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import packages

# %%
pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.3.1)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-23.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-23.7.0 scikit-optimize-0.9.0

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from skopt import BayesSearchCV
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from collections import OrderedDict
import itertools
from mlxtend.classifier import StackingClassifier as MLStackingClassifier
from sklearn.ensemble import StackingClassifier as SLStackingClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #Load data

# %%
data = load_breast_cancer()

# %%
df = pd.DataFrame(data.data, columns = data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# #Data properties

# %%
df.shape
# Out:
# (569, 31)

# %%
(df.isna().sum() == 0).all()
# Out:
# True

# %%
df.target.value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
df.dtypes
# Out:
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                 float64
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# worst concave points       float64
# worst symmetry             float64
# worst fractal dimension    float64
# target                       int64
# dtype: object

# %%
df.describe().T
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# area error               569.0   40.337079   45.491006    6.802000
# smoothness error         569.0    0.007041    0.003003    0.001713
# compactness error        569.0    0.025478    0.017908    0.002252
# concavity error          569.0    0.031894    0.030186    0.000000
# concave points error     569.0    0.011796    0.006170    0.000000
# symmetry error           569.0    0.020542    0.008266    0.007882
# fractal dimension error  569.0    0.003795    0.002646    0.000895
# worst radius             569.0   16.269190    4.833242    7.930000
# worst texture            569.0   25.677223    6.146258   12.020000
# worst perimeter          569.0  107.261213   33.602542   50.410000
# worst area               569.0  880.583128  569.356993  185.200000
# worst smoothness         569.0    0.132369    0.022832    0.071170
# worst compactness        569.0    0.254265    0.157336    0.027290
# worst concavity          569.0    0.272188    0.208624    0.000000
# worst concave points     569.0    0.114606    0.065732    0.000000
# worst symmetry           569.0    0.290076    0.061867    0.156500
# worst fractal dimension  569.0    0.083946    0.018061    0.055040
# target                   569.0    0.627417    0.483918    0.000000
#
#                                 25%         50%          75%         max
# mean radius               11.700000   13.370000    15.780000    28.11000
# mean texture              16.170000   18.840000    21.800000    39.28000
# mean perimeter            75.170000   86.240000   104.100000   188.50000
# mean area                420.300000  551.100000   782.700000  2501.00000
# mean smoothness            0.086370    0.095870     0.105300     0.16340
# mean compactness           0.064920    0.092630     0.130400     0.34540
# mean concavity             0.029560    0.061540     0.130700     0.42680
# mean concave points        0.020310    0.033500     0.074000     0.20120
# mean symmetry              0.161900    0.179200     0.195700     0.30400
# mean fractal dimension     0.057700    0.061540     0.066120     0.09744
# radius error               0.232400    0.324200     0.478900     2.87300
# texture error              0.833900    1.108000     1.474000     4.88500
# perimeter error            1.606000    2.287000     3.357000    21.98000
# area error                17.850000   24.530000    45.190000   542.20000
# smoothness error           0.005169    0.006380     0.008146     0.03113
# compactness error          0.013080    0.020450     0.032450     0.13540
# concavity error            0.015090    0.025890     0.042050     0.39600
# concave points error       0.007638    0.010930     0.014710     0.05279
# symmetry error             0.015160    0.018730     0.023480     0.07895
# fractal dimension error    0.002248    0.003187     0.004558     0.02984
# worst radius              13.010000   14.970000    18.790000    36.04000
# worst texture             21.080000   25.410000    29.720000    49.54000
# worst perimeter           84.110000   97.660000   125.400000   251.20000
# worst area               515.300000  686.500000  1084.000000  4254.00000
# worst smoothness           0.116600    0.131300     0.146000     0.22260
# worst compactness          0.147200    0.211900     0.339100     1.05800
# worst concavity            0.114500    0.226700     0.382900     1.25200
# worst concave points       0.064930    0.099930     0.161400     0.29100
# worst symmetry             0.250400    0.282200     0.317900     0.66380
# worst fractal dimension    0.071460    0.080040     0.092080     0.20750
# target                     0.000000    1.000000     1.000000     1.00000

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['target']), df.target, test_size=0.2, random_state=0)

# %% [markdown]
# #Estimators

# %% [markdown]
# Random Forest classifier

# %%
rd_hpars = {
    'n_estimators' : np.arange(100, 701, 200),
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_depth' : [None] + list(np.arange(5, 21, 5)),
    'max_features' : ['sqrt', 'log2', None],
    'min_samples_split' : [2] + list(np.arange(5, 51, 10)),
    'min_samples_leaf' : [1] + list(np.arange(5, 11, 5)),
    'bootstrap' : [True, False]
}

rd_hpars
# Out:
# {'n_estimators': array([100, 300, 500, 700]),
#  'criterion': ['gini', 'entropy', 'log_loss'],
#  'max_depth': [None, 5, 10, 15, 20],
#  'max_features': ['sqrt', 'log2', None],
#  'min_samples_split': [2, 5, 15, 25, 35, 45],
#  'min_samples_leaf': [1, 5, 10],
#  'bootstrap': [True, False]}

# %%
rd_grid = BayesSearchCV(estimator = RandomForestClassifier(random_state = 123),
                        search_spaces = rd_hpars,
                        n_iter = 50,
                        scoring = 'accuracy',
                        n_jobs = -1,
                        refit = True,
                        cv = 5,
                        verbose = 0,
                        random_state = 123)

rd_grid.fit(X_train, y_train)

rd_grid.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %%
rf_cv_results_df = pd.DataFrame(rd_grid.cv_results_)
rf_cv_results_df[rf_cv_results_df['rank_test_score'] <= 5].T
# Out:
#                                                                         23  \
# mean_fit_time                                                     1.549641
# std_fit_time                                                      0.200491
# mean_score_time                                                   0.056395
# std_score_time                                                    0.012454
# param_bootstrap                                                      False
# param_criterion                                                    entropy
# param_max_depth                                                         15
# param_max_features                                                    sqrt
# param_min_samples_leaf                                                   1
# param_min_samples_split                                                  5
# param_n_estimators                                                     500
# params                   {'bootstrap': False, 'criterion': 'entropy', '...
# split0_test_score                                                 0.956044
# split1_test_score                                                 0.967033
# split2_test_score                                                 0.923077
# split3_test_score                                                 0.956044
# split4_test_score                                                      1.0
# mean_test_score                                                    0.96044
# std_test_score                                                     0.02467
# rank_test_score                                                          2
#
#                                                                         26  \
# mean_fit_time                                                     1.818277
# std_fit_time                                                       0.14888
# mean_score_time                                                   0.060551
# std_score_time                                                    0.018257
# param_bootstrap                                                      False
# param_criterion                                                   log_loss
# param_max_depth                                                       None
# param_max_features                                                    sqrt
# param_min_samples_leaf                                                   1
# param_min_samples_split                                                  5
# param_n_estimators                                                     500
# params                   {'bootstrap': False, 'criterion': 'log_loss', ...
# split0_test_score                                                 0.956044
# split1_test_score                                                 0.967033
# split2_test_score                                                 0.923077
# split3_test_score                                                 0.956044
# split4_test_score                                                      1.0
# mean_test_score                                                    0.96044
# std_test_score                                                     0.02467
# rank_test_score                                                          2
#
#                                                                         40  \
# mean_fit_time                                                     2.240258
# std_fit_time                                                      0.038442
# mean_score_time                                                   0.085581
# std_score_time                                                    0.016764
# param_bootstrap                                                       True
# param_criterion                                                    entropy
# param_max_depth                                                         20
# param_max_features                                                    log2
# param_min_samples_leaf                                                   1
# param_min_samples_split                                                  2
# param_n_estimators                                                     700
# params                   {'bootstrap': True, 'criterion': 'entropy', 'm...
# split0_test_score                                                 0.967033
# split1_test_score                                                 0.967033
# split2_test_score                                                 0.923077
# split3_test_score                                                 0.956044
# split4_test_score                                                 0.989011
# mean_test_score                                                    0.96044
# std_test_score                                                    0.021534
# rank_test_score                                                          2
#
#                                                                         47  \
# mean_fit_time                                                     0.858688
# std_fit_time                                                      0.119866
# mean_score_time                                                   0.031841
# std_score_time                                                    0.005954
# param_bootstrap                                                      False
# param_criterion                                                   log_loss
# param_max_depth                                                         10
# param_max_features                                                    log2
# param_min_samples_leaf                                                   1
# param_min_samples_split                                                  2
# param_n_estimators                                                     300
# params                   {'bootstrap': False, 'criterion': 'log_loss', ...
# split0_test_score                                                 0.967033
# split1_test_score                                                 0.967033
# split2_test_score                                                 0.923077
# split3_test_score                                                 0.956044
# split4_test_score                                                      1.0
# mean_test_score                                                   0.962637
# std_test_score                                                     0.02467
# rank_test_score                                                          1
#
#                                                                         48
# mean_fit_time                                                     0.999964
# std_fit_time                                                      0.035932
# mean_score_time                                                   0.046606
# std_score_time                                                    0.014141
# param_bootstrap                                                       True
# param_criterion                                                   log_loss
# param_max_depth                                                       None
# param_max_features                                                    log2
# param_min_samples_leaf                                                   1
# param_min_samples_split                                                  2
# param_n_estimators                                                     300
# params                   {'bootstrap': True, 'criterion': 'log_loss', '...
# split0_test_score                                                 0.956044
# split1_test_score                                                 0.967033
# split2_test_score                                                 0.923077
# split3_test_score                                                 0.967033
# split4_test_score                                                 0.989011
# mean_test_score                                                    0.96044
# std_test_score                                                    0.021534
# rank_test_score                                                          2

# %%
rd_grid.best_params_
# Out:
# OrderedDict([('bootstrap', False),
#              ('criterion', 'log_loss'),
#              ('max_depth', 10),
#              ('max_features', 'log2'),
#              ('min_samples_leaf', 1),
#              ('min_samples_split', 2),
#              ('n_estimators', 300)])

# %%
rf_clf = RandomForestClassifier(**dict(OrderedDict([('bootstrap', False),
             ('criterion', 'log_loss'),
             ('max_depth', 10),
             ('max_features', 'log2'),
             ('min_samples_leaf', 1),
             ('min_samples_split', 2),
             ('n_estimators', 300)])))

rf_clf.fit(X_train, y_train)

rf_clf.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %% [markdown]
# Gradient boosting classifier

# %%
gb_hpars = {
    'n_estimators' : np.arange(100, 701, 200),
    'learning_rate' : [0.001, 0.01, 0.1],
    'loss' : ['log_loss', 'exponential'],
    'criterion' : ['friedman_mse', 'squared_error'],
    'max_depth' : [None] + list(np.arange(5, 21, 5)),
    'max_features' : ['sqrt', 'log2', None],
    'min_samples_split' : [2] + list(np.arange(5, 51, 10)),
    'min_samples_leaf' : [1] + list(np.arange(5, 11, 5))
}

gb_hpars
# Out:
# {'n_estimators': array([100, 300, 500, 700]),
#  'learning_rate': [0.001, 0.01, 0.1],
#  'loss': ['log_loss', 'exponential'],
#  'criterion': ['friedman_mse', 'squared_error'],
#  'max_depth': [None, 5, 10, 15, 20],
#  'max_features': ['sqrt', 'log2', None],
#  'min_samples_split': [2, 5, 15, 25, 35, 45],
#  'min_samples_leaf': [1, 5, 10]}

# %%
gb_grid = BayesSearchCV(estimator = GradientBoostingClassifier(random_state = 123),
                        search_spaces = gb_hpars,
                        n_iter = 50,
                        scoring = 'accuracy',
                        n_jobs = -1,
                        refit = True,
                        cv = 5,
                        verbose = 0,
                        random_state = 123)

gb_grid.fit(X_train, y_train)

gb_grid.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %%
gb_cv_results_df = pd.DataFrame(gb_grid.cv_results_)
gb_cv_results_df[gb_cv_results_df['rank_test_score'] <= 5].T
# Out:
#                                                                         9   \
# mean_fit_time                                                     1.868153
# std_fit_time                                                      0.498372
# mean_score_time                                                   0.007254
# std_score_time                                                    0.003396
# param_criterion                                               friedman_mse
# param_learning_rate                                                    0.1
# param_loss                                                     exponential
# param_max_depth                                                         15
# param_max_features                                                    log2
# param_min_samples_leaf                                                   5
# param_min_samples_split                                                  2
# param_n_estimators                                                     300
# params                   {'criterion': 'friedman_mse', 'learning_rate':...
# split0_test_score                                                 0.967033
# split1_test_score                                                 0.978022
# split2_test_score                                                 0.945055
# split3_test_score                                                 0.967033
# split4_test_score                                                      1.0
# mean_test_score                                                   0.971429
# std_test_score                                                    0.017855
# rank_test_score                                                          1
#
#                                                                         17  \
# mean_fit_time                                                     0.761194
# std_fit_time                                                      0.143413
# mean_score_time                                                   0.005371
# std_score_time                                                    0.000986
# param_criterion                                               friedman_mse
# param_learning_rate                                                    0.1
# param_loss                                                     exponential
# param_max_depth                                                          5
# param_max_features                                                    log2
# param_min_samples_leaf                                                  10
# param_min_samples_split                                                 35
# param_n_estimators                                                     300
# params                   {'criterion': 'friedman_mse', 'learning_rate':...
# split0_test_score                                                 0.956044
# split1_test_score                                                 0.989011
# split2_test_score                                                 0.934066
# split3_test_score                                                 0.967033
# split4_test_score                                                 0.989011
# mean_test_score                                                   0.967033
# std_test_score                                                     0.02085
# rank_test_score                                                          5
#
#                                                                         19  \
# mean_fit_time                                                     1.088125
# std_fit_time                                                      0.150031
# mean_score_time                                                   0.005322
# std_score_time                                                     0.00077
# param_criterion                                               friedman_mse
# param_learning_rate                                                    0.1
# param_loss                                                        log_loss
# param_max_depth                                                          5
# param_max_features                                                    log2
# param_min_samples_leaf                                                   5
# param_min_samples_split                                                  5
# param_n_estimators                                                     700
# params                   {'criterion': 'friedman_mse', 'learning_rate':...
# split0_test_score                                                 0.967033
# split1_test_score                                                 0.967033
# split2_test_score                                                 0.945055
# split3_test_score                                                 0.956044
# split4_test_score                                                      1.0
# mean_test_score                                                   0.967033
# std_test_score                                                    0.018388
# rank_test_score                                                          5
#
#                                                                         28  \
# mean_fit_time                                                     0.387955
# std_fit_time                                                      0.066251
# mean_score_time                                                   0.004676
# std_score_time                                                    0.000623
# param_criterion                                               friedman_mse
# param_learning_rate                                                    0.1
# param_loss                                                     exponential
# param_max_depth                                                         15
# param_max_features                                                    log2
# param_min_samples_leaf                                                   5
# param_min_samples_split                                                 45
# param_n_estimators                                                     100
# params                   {'criterion': 'friedman_mse', 'learning_rate':...
# split0_test_score                                                 0.956044
# split1_test_score                                                 0.978022
# split2_test_score                                                 0.945055
# split3_test_score                                                 0.967033
# split4_test_score                                                      1.0
# mean_test_score                                                   0.969231
# std_test_score                                                    0.018906
# rank_test_score                                                          3
#
#                                                                         29  \
# mean_fit_time                                                     1.180921
# std_fit_time                                                      0.197748
# mean_score_time                                                   0.006557
# std_score_time                                                    0.001128
# param_criterion                                               friedman_mse
# param_learning_rate                                                    0.1
# param_loss                                                        log_loss
# param_max_depth                                                         15
# param_max_features                                                    log2
# param_min_samples_leaf                                                  10
# param_min_samples_split                                                  2
# param_n_estimators                                                     500
# params                   {'criterion': 'friedman_mse', 'learning_rate':...
# split0_test_score                                                 0.978022
# split1_test_score                                                 0.978022
# split2_test_score                                                 0.934066
# split3_test_score                                                 0.967033
# split4_test_score                                                      1.0
# mean_test_score                                                   0.971429
# std_test_score                                                    0.021534
# rank_test_score                                                          1
#
#                                                                         34
# mean_fit_time                                                     1.036737
# std_fit_time                                                      0.176683
# mean_score_time                                                    0.00668
# std_score_time                                                    0.001935
# param_criterion                                               friedman_mse
# param_learning_rate                                                    0.1
# param_loss                                                        log_loss
# param_max_depth                                                         15
# param_max_features                                                    log2
# param_min_samples_leaf                                                   5
# param_min_samples_split                                                 35
# param_n_estimators                                                     300
# params                   {'criterion': 'friedman_mse', 'learning_rate':...
# split0_test_score                                                 0.978022
# split1_test_score                                                 0.978022
# split2_test_score                                                 0.923077
# split3_test_score                                                 0.967033
# split4_test_score                                                      1.0
# mean_test_score                                                   0.969231
# std_test_score                                                    0.025441
# rank_test_score                                                          3

# %%
gb_grid.best_params_
# Out:
# OrderedDict([('criterion', 'friedman_mse'),
#              ('learning_rate', 0.1),
#              ('loss', 'exponential'),
#              ('max_depth', 15),
#              ('max_features', 'log2'),
#              ('min_samples_leaf', 5),
#              ('min_samples_split', 2),
#              ('n_estimators', 300)])

# %%
gb_clf = GradientBoostingClassifier(**dict(OrderedDict([('criterion', 'friedman_mse'),
             ('learning_rate', 0.1),
             ('loss', 'exponential'),
             ('max_depth', 15),
             ('max_features', 'log2'),
             ('min_samples_leaf', 5),
             ('min_samples_split', 2),
             ('n_estimators', 300)])))

gb_clf.fit(X_train, y_train)

gb_clf.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %% [markdown]
# SVM

# %%
svm_hpars = {
    'svc__C' : [1, 2, 3, 4, 5, 7],
    'svc__kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__degree' : np.arange(2, 7, 1),
    'svc__gamma' : ['scale', 'auto'],
}

svm_hpars
# Out:
# {'svc__C': [1, 2, 3, 4, 5, 7],
#  'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#  'svc__degree': array([2, 3, 4, 5, 6]),
#  'svc__gamma': ['scale', 'auto']}

# %%
svm_grid = BayesSearchCV(estimator = Pipeline(steps=[("standardscaler", StandardScaler()), ("svc", SVC())]),
                        search_spaces = svm_hpars,
                        n_iter = 50,
                        scoring = 'accuracy',
                        n_jobs = -1,
                        refit = True,
                        cv = 5,
                        verbose = 0,
                        random_state = 123)

svm_grid.fit(X_train, y_train)

svm_grid.score(X_test, y_test)
# Out:
# 0.9912280701754386

# %%
svm_cv_results_df = pd.DataFrame(svm_grid.cv_results_)
svm_cv_results_df[svm_cv_results_df['rank_test_score'] <= 5].T
# Out:
#                                                                   4   \
# mean_fit_time                                               0.034412
# std_fit_time                                                0.008668
# mean_score_time                                             0.013316
# std_score_time                                              0.008042
# param_svc__C                                                       3
# param_svc__degree                                                  4
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 3, 'svc__degree': 4, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   10  \
# mean_fit_time                                               0.016118
# std_fit_time                                                0.005598
# mean_score_time                                             0.006943
# std_score_time                                              0.002726
# param_svc__C                                                       3
# param_svc__degree                                                  4
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 3, 'svc__degree': 4, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   13  \
# mean_fit_time                                               0.020571
# std_fit_time                                                0.007484
# mean_score_time                                             0.008283
# std_score_time                                                0.0033
# param_svc__C                                                       2
# param_svc__degree                                                  5
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 5, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   16  \
# mean_fit_time                                                0.02151
# std_fit_time                                                0.006709
# mean_score_time                                             0.009371
# std_score_time                                              0.003688
# param_svc__C                                                       2
# param_svc__degree                                                  5
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 5, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   20  \
# mean_fit_time                                                0.01912
# std_fit_time                                                 0.00696
# mean_score_time                                             0.006003
# std_score_time                                              0.002138
# param_svc__C                                                       3
# param_svc__degree                                                  5
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 3, 'svc__degree': 5, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   21  \
# mean_fit_time                                               0.030581
# std_fit_time                                                0.010213
# mean_score_time                                             0.012159
# std_score_time                                              0.005248
# param_svc__C                                                       3
# param_svc__degree                                                  6
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 3, 'svc__degree': 6, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   22  \
# mean_fit_time                                                0.01941
# std_fit_time                                                0.007091
# mean_score_time                                              0.00708
# std_score_time                                              0.003355
# param_svc__C                                                       2
# param_svc__degree                                                  2
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 2, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   31  \
# mean_fit_time                                               0.023393
# std_fit_time                                                0.008689
# mean_score_time                                              0.00544
# std_score_time                                              0.001131
# param_svc__C                                                       2
# param_svc__degree                                                  3
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 3, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   33  \
# mean_fit_time                                               0.026104
# std_fit_time                                                0.007274
# mean_score_time                                             0.007889
# std_score_time                                              0.004805
# param_svc__C                                                       3
# param_svc__degree                                                  3
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 3, 'svc__degree': 3, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   34  \
# mean_fit_time                                               0.015075
# std_fit_time                                                0.004691
# mean_score_time                                             0.006659
# std_score_time                                               0.00382
# param_svc__C                                                       3
# param_svc__degree                                                  2
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 3, 'svc__degree': 2, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   35  \
# mean_fit_time                                               0.017751
# std_fit_time                                                0.006545
# mean_score_time                                              0.00689
# std_score_time                                              0.002678
# param_svc__C                                                       2
# param_svc__degree                                                  6
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 6, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   42  \
# mean_fit_time                                               0.021642
# std_fit_time                                                0.003516
# mean_score_time                                             0.009677
# std_score_time                                              0.002517
# param_svc__C                                                       2
# param_svc__degree                                                  4
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 4, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   43  \
# mean_fit_time                                               0.017418
# std_fit_time                                                0.005497
# mean_score_time                                             0.007342
# std_score_time                                              0.003851
# param_svc__C                                                       2
# param_svc__degree                                                  2
# param_svc__gamma                                                auto
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 2, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   45  \
# mean_fit_time                                               0.016604
# std_fit_time                                                0.006396
# mean_score_time                                             0.005271
# std_score_time                                               0.00155
# param_svc__C                                                       2
# param_svc__degree                                                  4
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 4, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1
#
#                                                                   48
# mean_fit_time                                               0.016641
# std_fit_time                                                0.007187
# mean_score_time                                             0.006382
# std_score_time                                              0.002514
# param_svc__C                                                       2
# param_svc__degree                                                  3
# param_svc__gamma                                               scale
# param_svc__kernel                                                rbf
# params             {'svc__C': 2, 'svc__degree': 3, 'svc__gamma': ...
# split0_test_score                                           0.978022
# split1_test_score                                           0.989011
# split2_test_score                                           0.945055
# split3_test_score                                           0.978022
# split4_test_score                                                1.0
# mean_test_score                                             0.978022
# std_test_score                                              0.018388
# rank_test_score                                                    1

# %%
svm_grid.best_params_
# Out:
# OrderedDict([('svc__C', 3),
#              ('svc__degree', 4),
#              ('svc__gamma', 'auto'),
#              ('svc__kernel', 'rbf')])

# %%
sv_clf = Pipeline(steps=[("standardscaler", StandardScaler()), ("svc", SVC(**dict(OrderedDict([('C', 3),
             ('degree', 4),
             ('gamma', 'auto'),
             ('kernel', 'rbf'),
             ('probability', True) ]))))])

sv_clf.fit(X_train, y_train)

sv_clf.score(X_test, y_test)
# Out:
# 0.9912280701754386

# %% [markdown]
# #Voting

# %%
#weights based on scoring
scores = [f.score(X_test, y_test) for f in (rf_clf, gb_clf, sv_clf)]
score_weights = scores / sum(scores)
score_weights
# Out:
# array([0.33035714, 0.33333333, 0.33630952])

# %%
weights = pd.Series(score_weights).map({e: i+1 for i, e in enumerate(sorted(set(score_weights)))}).values
weights
# Out:
# array([1, 2, 3])

# %%
#majority voting with weights
clf_voting = VotingClassifier(
    estimators=[
       ('rf', rf_clf),
       ('gb', gb_clf),
       ('sv', sv_clf)],
    voting='hard',
    weights = weights)

clf_voting.fit(X_train, y_train)
clf_voting.score(X_test, y_test)
# Out:
# 0.9912280701754386

# %%
#majority voting without weights
clf_voting = VotingClassifier(
    estimators=[
       ('rf', rf_clf),
       ('gb', gb_clf),
       ('sv', sv_clf)],
    voting='hard')

clf_voting.fit(X_train, y_train)
clf_voting.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %%
#averaging with weights
clf_voting = VotingClassifier(
    estimators=[
       ('rf', rf_clf),
       ('gb', gb_clf),
       ('sv', sv_clf)],
    voting='soft',
    weights = weights)

clf_voting.fit(X_train, y_train)
clf_voting.score(X_test, y_test)
# Out:
# 0.9912280701754386

# %%
#averaging without weights
clf_voting = VotingClassifier(
    estimators=[
       ('rf', rf_clf),
       ('gb', gb_clf),
       ('sv', sv_clf)],
    voting='soft')

clf_voting.fit(X_train, y_train)
clf_voting.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %%
#weights for fine-tuning
all = list(itertools.product([1, 2],[1, 2], [1, 2]))

weights = {'weights' : [x for x in all if not (np.array(x) == max(x)).all() == True ] + [(1, 1, 1)]}
weights
# Out:
# {'weights': [(1, 1, 2),
#   (1, 2, 1),
#   (1, 2, 2),
#   (2, 1, 1),
#   (2, 1, 2),
#   (2, 2, 1),
#   (1, 1, 1)]}

# %%
#grid search for fine-tuning for majority voting
vot_grid = GridSearchCV(estimator = VotingClassifier(
                                    estimators=[
                                      ('rf', rf_clf),
                                      ('gb', gb_clf),
                                      ('sv', sv_clf)],
                                    voting='hard'),
                        param_grid = weights,
                        scoring = 'accuracy',
                        n_jobs = -1,
                        refit = True,
                        cv = 5,
                        verbose = 0)

vot_grid.fit(X_train, y_train)

vot_grid.score(X_test, y_test)
# Out:
# 0.9912280701754386

# %%
#same result as before
vot_grid.best_params_
# Out:
# {'weights': (1, 1, 2)}

# %%
#grid search for fine-tuning for average voting
vot_grid = GridSearchCV(estimator = VotingClassifier(
                                    estimators=[
                                      ('rf', rf_clf),
                                      ('gb', gb_clf),
                                      ('sv', sv_clf)],
                                    voting='soft'),
                        param_grid = weights,
                        scoring = 'accuracy',
                        n_jobs = -1,
                        refit = True,
                        cv = 5,
                        verbose = 0)

vot_grid.fit(X_train, y_train)

vot_grid.score(X_test, y_test)
# Out:
# 0.9912280701754386

# %%
#same result as before
vot_grid.best_params_
# Out:
# {'weights': (1, 1, 2)}

# %% [markdown]
# #Stacking

# %% [markdown]
# MLExtend

# %%
st_clf = MLStackingClassifier(classifiers = [rf_clf, gb_clf, sv_clf],
                             meta_classifier = LogisticRegression())

# %%
st_hpars = {'meta_classifier__C': [0.09, 0.1, 0.11]}
st_hpars
# Out:
# {'meta_classifier__C': [0.09, 0.1, 0.11]}

# %%
st_grid = GridSearchCV(estimator = st_clf,
                      param_grid = st_hpars,
                      scoring = 'accuracy',
                      n_jobs = -1,
                      refit = True,
                      cv = 5,
                      verbose = 0)

st_grid.fit(X_train, y_train)

st_grid.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %%
st_grid.best_params_
# Out:
# {'meta_classifier__C': 0.09}

# %% [markdown]
# Scikit Learn

# %%
st_clf = SLStackingClassifier(estimators = [('rf', rf_clf), ('gb', gb_clf), ('sv', sv_clf)],
                              final_estimator = LogisticRegression())

# %%
st_hpars = {'final_estimator__C': [0.08, 0.09, 0.1]}
st_hpars
# Out:
# {'final_estimator__C': [0.08, 0.09, 0.1]}

# %%
st_grid = GridSearchCV(estimator = st_clf,
                      param_grid = st_hpars,
                      scoring = 'accuracy',
                      n_jobs = -1,
                      refit = True,
                      cv = 5,
                      verbose = 0)

st_grid.fit(X_train, y_train)

st_grid.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %%
st_grid.best_params_
# Out:
# {'final_estimator__C': 0.09}
